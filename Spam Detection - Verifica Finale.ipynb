# %% [markdown]
# ## SPAM DETECTION

# %%
import pandas as pd

# %%
dataset = pd.read_csv('datasets/Verifica Finale - Spam Detection/spam_ham_dataset.csv')

# %%
dataset
# Out:
#       Unnamed: 0 label                                               text  \
# 0            605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1           2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2           3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3           4685  spam  Subject: photoshop , windows , office . cheap ...
# 4           2030   ham  Subject: re : indian springs\r\nthis deal is t...
# ...          ...   ...                                                ...
# 5166        1518   ham  Subject: put the 10 on the ft\r\nthe transport...
# 5167         404   ham  Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168        2933   ham  Subject: calpine daily gas nomination\r\n>\r\n...
# 5169        1409   ham  Subject: industrial worksheets for august 2000...
# 5170        4807  spam  Subject: important online banking alert\r\ndea...
#
#       label_num
# 0             0
# 1             0
# 2             0
# 3             1
# 4             0
# ...         ...
# 5166          0
# 5167          0
# 5168          0
# 5169          0
# 5170          1
#
# [5171 rows x 4 columns]

# %%
import string
import spacy
from nltk.corpus import stopwords
import re

english_stopwords = stopwords.words('english')
nlp = spacy.load('en_core_web_sm')
punctuation = set(string.punctuation)

def data_cleaner(sentence):
    sentence = sentence.lower()
    for c in string.punctuation:
        sentence = sentence.replace(c, " ")
    document = nlp(sentence)
    sentence = ' '.join(token.lemma_ for token in document)
    sentence = ' '.join(word for word in sentence.split() if word not in english_stopwords)
    sentence = sentence.replace('\n',' ')
    sentence = sentence.replace('subject',' ')
    sentence = re.sub('\d', '', sentence)
    
    return sentence

# %%
subject = []
contents = []
for i in range(0,len(dataset['text'])):
    c = dataset['text'][i].split('\n')
    subject.append(c[0].replace('Subject: ',''))
    text = ""
    for j in range(1,len(c)):
        text = text + " " +c[j]
    contents.append(text)

# %%
subject
# Out:
# ['enron methanol ; meter # : 988291\r',
#  'hpl nom for january 9 , 2001\r',
#  'neon retreat\r',
#  'photoshop , windows , office . cheap . main trending\r',
#  're : indian springs\r',
#  'ehronline web address change\r',
#  'spring savings certificate - take 30 % off\r',
#  'looking for medication ? we ` re the best source .\r',
#  'noms / actual flow for 2 / 26\r',
#  'nominations for oct . 21 - 23 , 2000\r',
#  'vocable % rnd - word asceticism\r',
#  'report 01405 !\r',
#  'enron / hpl actuals for august 28 , 2000\r',
#  'vic . odin n ^ ow\r',
#  'tenaska iv july\r',
#  'underpriced issue with high return on equity\r',
#  're : first delivery - wheeler operating\r',
#  'swift - may 2001 vols\r',
#  'meter variances - ua 4 clean - up\r',
#  'additional recruiting\r',
#  'fw : ercot load comparison\r',
#  'meter 6461 , concorde churchill\r',
#  'hpl nom for january 25 , 2001\r',
#  're : tenaska iv 10 / 00\r',
#  'jump in to gain substantial ground immediately\r',
#  're : enron / hpl actuals for october 11 , 2000 - revision\r',
#  'registration confirmation from spinner . com\r',
#  'aep transition items\r',
#  'an inbound message for you has been quarantined\r',
#  're : valero gas marketing ; meter # : 8018 / sitara ticket # 148376\r',
#  'the houston expl dec 2000\r',
#  'enron / hpl actuals for october 2 , 2000\r',
#  'to : all domestic employees who participate in the enron corp\r',
#  're : new eol product\r',
#  'pathing procedures for buybacks\r',
#  'end of year clearance\r',
#  'enron actuals for june 02 thru 04 , 2000\r',
#  'on - call notes\r',
#  '19 th noms on copanos\r',
#  'lst rev feb . 2000 josey ranch nom\r',
#  'vlc , 0 dln for sale , no prior pres . crip . tion needed\r',
#  'jennifer\r',
#  'calpine daily gas nomination\r',
#  'enron / hpl actuals for october 5 , 2000\r',
#  're : potential volume list for march , 2000\r',
#  're : new production - sitara deals needed\r',
#  'software\r',
#  'security alert on microsoft internet explorer\r',
#  'instant download 1300 popular softwares now\r',
#  'fw : fw : gap gift certificates\r',
#  'notification of bequest\r',
#  'april , 2001 gathering contracts\r',
#  'expense report receipts not received\r',
#  'new enrononline functionality\r',
#  're : pg & e texas meeting\r',
#  'adjusted deal ticket\r',
#  're : cornhusker - lone star payments\r',
#  'enron / hpl actuals for september 22 - 24 , 2000\r',
#  're : nom / actual flow for april 4 th\r',
#  'equistar\r',
#  'the bull reccomends this stokkpic\r',
#  'fw : txu fuel deals imbalances\r',
#  'epgt\r',
#  'ehronline web address change\r',
#  'fw : chevron phillips chemical co . , lp ( hplc 04 / 01 sales / buyback )\r',
#  'hpl noms . for jan . 17 , 2001\r',
#  'eastrans nomination change effective 8 / 8 / 00\r',
#  'resume - anna cola\r',
#  're : husband soup would be\r',
#  'deal # 502952\r',
#  'active and strong\r',
#  '- get a dell laptop computer free !\r',
#  'revised avails for 12 / 00 as noted\r',
#  'howdy to you too .\r',
#  'back\r',
#  'new schedule\r',
#  'northern natural gas\r',
#  're : tenaska iv\r',
#  'oasis on - line\r',
#  '@ ect . enron . com email notification !\r',
#  're : free agents\r',
#  '21 st changes\r',
#  're : noms / actual vol for april 22 nd\r',
#  'hpl nom for november 14 , 2000\r',
#  'pat - out for jury duty\r',
#  '108 mbps wireless firewall 4 - port router @ $ 59 . 00\r',
#  'income tax\r',
#  'enron nom for march 7 , 2001\r',
#  'meter # 1591 lamay gaslift\r',
#  'quack\r',
#  'vulgar\r',
#  'smal | stock oppurtunities - their shooting\r',
#  'tinydrive usb 2 . 0 mobile 2 . 2 gb storage drive @ $ 187 . 00\r',
#  'pay less for microsoft office software\r',
#  'young sluts had sex for tewnty bucks\r',
#  'take 30 % off with our super ticket !\r',
#  'updated list\r',
#  'hpl nom for march 27 , 2001\r',
#  'what she doesnt know sprig bashaw\r',
#  'mobil beaumont\r',
#  'help !\r',
#  'fw : ena origination track\r',
#  'password reset\r',
#  'lose 19 % , powerful weightloss now available where you are .\r',
#  '\r',
#  'woops . . . .\r',
#  'buy pain relief medicine at unbelievable prices\r',
#  'nom for 2 / 16 / 00\r',
#  '7 th noms\r',
#  'about celebration\r',
#  'cialis , valium , viagra , xanax at low price ! no prescription needed !\r',
#  'cox exploration\r',
#  'february and march 2000 meter 5688\r',
#  'mitchell gas services 2 / 00\r',
#  'kcs resources nom - april 1\r',
#  'young pussies\r',
#  'settelement request for an equistar " buyback " ticket with ena as\r',
#  're : lindholm oil , inc .\r',
#  'noms / actual flow for 14 th / 15 th\r',
#  'nom for 2 / 17\r',
#  'txu noms . for 3 / 14 / 01\r',
#  'txu noms . for 10 / 14 - 16 / 00\r',
#  're : txu fuel deals imbalances\r',
#  'hpl meter # 980417 hpl / kmid - seven oaks\r',
#  'the bast phharma out ther - same da - y shijpping ! chromium\r',
#  're : cornhusker\r',
#  'notebookplus batteries\r',
#  'exxon company , usa global # 96035668 / sitara # 212225\r',
#  '= ? iso - 8859 - 7 ? q ? = 5 b = 3 f = 5 d _ fwd : continuous _ gr = f 4 wth _ with _ the _ pill ? =\r',
#  ' ?  r  s ? ? ? ? ? ???  apaliourg @ iit . demokritos . gr\r',
#  'september production estimate\r',
#  '" ram tackett " : pictures\r',
#  'duplicates\r',
#  're : noms / actual flow for 3 / 29 / 01\r',
#  'new * cial \\ is softtabs , save 80 %\r',
#  'from mrs . juliana\r',
#  're : tuesday , december 26 th\r',
#  'application update\r',
#  'cat\r',
#  "my brother ' s dream one nlght , i lay in bed reading , and i heard robert in the shower , singing a song gently .\r",
#  'fw : fw : equistar 1373 for march\r',
#  'collene medg stockplay of the day jeer\r',
#  're : texas general land office it transport\r',
#  're : panenergy 9 / 00\r',
#  'penls enlarg 3 ment pllls\r',
#  'hpl nomination changes for july 25 and july 26\r',
#  '98 - 3405 activity being allocated / nomed @ 98 - 9643\r',
#  '[ adv ] access to the images of the catalogues - accedez aux images des catalogues\r',
#  'new locations\r',
#  'copanno changes\r',
#  'nom / actual flow for 2 / 22 / 01\r',
#  're : meter # : 1266 ; august 2000 / allocation exception\r',
#  'meter 986899 for november\r',
#  'oasis transport imbalances\r',
#  '\r',
#  're : basin production from ga 213\r',
#  'please process immediately to avoid loss of information\r',
#  'time is right to invest in the euro - 657549\r',
#  're : aekdju , the cat raised\r',
#  'notes from initial enom use case meeting - 2 / 2 / 00\r',
#  'memo and presentation from brian redmond\r',
#  'enron nom for february 16 , 2001\r',
#  'holiday e - cards\r',
#  ', si , ze does - matt ` er ; no r " eally ^ fyjlxqcbp\r',
#  'oem software at cheap prices - fortnight\r',
#  'from your coach\r',
#  'equistar sale off of tejas or midcon\r',
#  'hpl meter # 985579\r',
#  'new nomination - tejas\r',
#  're : october wellhead\r',
#  'zero path termination in path manager\r',
#  're : e mail list for class\r',
#  're : lst rev feb . 2000 josey ranch nom\r',
#  'well head\r',
#  'eastrans october first of the month nominations\r',
#  'we have all your favorite programs at incredibly low prices\r',
#  'toshiba manufacturer refurbished notebooks\r',
#  'enron / hpl acutals for october 3 , 2000\r',
#  'transport contracts\r',
#  'microsoft update warning - january 7 th\r',
#  '\r',
#  'global octane for may 2000\r',
#  '\r',
#  're : industrial report\r',
#  'buy cheap prescription drugs online dd\r',
#  'november prelim wellhead production - estimate\r',
#  'my phone number\r',
#  're : deal 338634 meter 985077\r',
#  'enron / hpl actuals for december 1 - 3 , 2000\r',
#  'ponderosa pine energy plant - start - up\r',
#  're : glo / egm gas / crude swap\r',
#  'young sluts getting creamy facials for $ 1 . 95\r',
#  'panenergy 9 / 00\r',
#  'meters\r',
#  're : centana mobil april 00\r',
#  'hello\r',
#  'martin luther king day\r',
#  'rincon petroleum corp\r',
#  'nomination change\r',
#  'march business - meter 6490 - help\r',
#  'automate load of scheduled quantity sirpo 0067\r',
#  'tech - support @ service . juno . com : problems retrieving mail\r',
#  'enron / hpl actuals for november 13 , 2000\r',
#  're : nomination - 2 - 23 - 2000\r',
#  '98 - 0432\r',
#  'pops production downtime request\r',
#  'calpine daily gas nomination\r',
#  'fw : auto - termination deal listing - part 3\r',
#  'payment confirmation p 9990835\r',
#  'hpl curtailment plan\r',
#  'increase into midcon\r',
#  'revised availabilities effective 8 / 01 / 00\r',
#  'new noms\r',
#  'how are you today ?\r',
#  'fw : epgt\r',
#  'bankruptcy management committee\r',
#  're : tenaska iv 10 / 00\r',
#  'july 25 , 2000\r',
#  '\r',
#  'breaking news : abdv goes energy epgqlahhkqqltj waanmdp\r',
#  'hpl nom for august 3 , 2000\r',
#  'calpine for 5 / 12 thru 5 / 14 ( 1465 )\r',
#  'hl & p for 12 / 99\r',
#  'low rate credit\r',
#  'photoshop , windows , office . cheap . cyclops baseball\r',
#  'mips january actuals\r',
#  'second revision to my spreadsheet - changes to previous one are\r',
#  'united salt quote\r',
#  'revision # 1 - enron / hpl actuals for july 5 , 2000\r',
#  'registration welcome email\r',
#  '2 nd rev mar . 2000 josey ranch nom\r',
#  'c , | alis soft ` tabs , fast shipping `\r',
#  'our recommendations make you big money\r',
#  '? ? ? , ? > ? ? ? ? ? ?\r',
#  'organizational announcement\r',
#  '24 x 5 products\r',
#  'this is the book my friend was talking about\r',
#  'hpl meter # 981511 pt arthur refinery - chevron hpl\r',
#  'transaction confirmation sheets\r',
#  'long time\r',
#  'revision # 1 - hpl nom for july 25 , 2000\r',
#  '$ 55486\r',
#  'october deals\r',
#  'roller coaster cigars for 9280\r',
#  'get cheap via - gra\r',
#  'fw : chevron phillips chemical co . , lp ( hplc 04 / 01 sales / buyback )\r',
#  're : i know what you wish for\r',
#  're : new production - sitara deals needed\r',
#  'no more high rates\r',
#  'tufco deal 108058\r',
#  '! ebay reguiar verification\r',
#  'october 2000 availabilities\r',
#  're : allocation exceptions\r',
#  'the best prize for cigarettes out there\r',
#  'sec information / earnings restatement\r',
#  'increase the volume of your ejaculation .\r',
#  'full stock of all your p # harmacy needs ! n 9\r',
#  "your specialist ' s appointment starts on the 8 th\r",
#  'huge savings on phentermine - all meds delivered overnight\r',
#  '98 - 6719 and 98 - 9676\r',
#  'cheating house wife services\r',
#  'nb real vallum , x . anax , l . evitra . . soma . . much more . . . . . . us p ` harmacies\r',
#  're : hl & p\r',
#  'ec 335 , ei 305 and smi 23 revision effective 6 / 10 / 00 ( sea robin\r',
#  'cheap online drugs here\r',
#  'enron / hpl actuals for september 21 , 2000\r',
#  'urgent assistance\r',
#  '( see attached file : hplo 916 . xls )\r',
#  're : coastal o & g , mtr . 4179 , goliad co .\r',
#  'nom change at the garza / trevino plant on tejas\r',
#  'cornhusker up on 24 th\r',
#  'february 2000 production , pg & e discrepancy for 02 / 24 / 00 ( pan\r',
#  'now i know bundle famish\r',
#  'wellhead nominations\r',
#  'get a bu _ lky p ^ 0 le * dcrgvabyssyzbr\r',
#  'duke energy field 9 / 00\r',
#  "nvhcs bvy h ' y _ d _ roc _ 0 _ d _ 0 ` n _ e online , f . r . ee overnight ship . ping\r",
#  'freedom ? ? ?\r',
#  'unify enhancement tracking list for ena upstream\r',
#  're : tuesday , december 26 th\r',
#  'nomination 2 / 3 / 2000\r',
#  'hello brother - are you fat\r',
#  'hpl nom for july 15 thru 17 , 2000\r',
#  'natural gas nomination for 03 / 00\r',
#  'cialis , xanax , valium , viagra at low price ! no prescription needed !\r',
#  'hpl noms - revisons for dec . 27 and 28 , 2000\r',
#  'hl & p month to date flow\r',
#  're : meter 0980438 - acock production ? ? ? ? ? ?\r',
#  'hpl nom for october 5 , 2000\r',
#  'co - owner vols 12 / 00\r',
#  're : nom / vols for 3 / 24 thru 3 / 26 / 01\r',
#  'accumuiate at these leveis with breakout lo 0 ming\r',
#  're : deal extension for 11 / 21 / 2000 for 98 - 439\r',
#  're : big cow breakout\r',
#  'natural gas nomination for 11 / 00\r',
#  'soul mate\r',
#  '\r',
#  'tenaska iv receivables\r',
#  'wild fuck of this pretty slutty mom ! . . . amicable\r',
#  '- - - - - - - - - - - - - - - - - - - - - - forwarded by ami chokshi / corp / enron on 03 / 21 / 2000\r',
#  'enron / hpl actuals for august 24 , 2000\r',
#  'sexually - explicit : angelina jolie strip . ped and n . aked\r',
#  'request submitted : access request for liz . bellamy @ enron . com\r',
#  're : noms / actual vols for 3 / 26 / 01\r',
#  'clickathome - msn internet service available\r',
#  '\r',
#  'fw : gop action plan : what you can do !\r',
#  'enron / hpl actuals for july 19 , 2000\r',
#  're : feb 01 prod : sale to teco gas processing\r',
#  'heads - up - tenaska iv partner ltd . - september 2000\r',
#  'pimpwear\r',
#  'eastrans nomination change effective 11 / 15 / 00\r',
#  'kerr mcgee : tomcat\r',
#  'saxet thompsonville - shut - in gas\r',
#  '\r',
#  're : cowtrap allocation - 4 / 01\r',
#  'hgpl and kgpl - 3 rivers gas\r',
#  '87 , 847 bottles sold daily - slze matters ! 6 ppntufbis\r',
#  're : milf neighbors lookin for . . . fbs\r',
#  'shoreline gas inc . , buhler central point\r',
#  'well head\r',
#  'revised again : revised : eastrans nomination change effective\r',
#  '10 / 2000 - days 6 and 19 ( 98 - 0439 )\r',
#  'enron avails - jan , 2001 revised\r',
#  'lagrangian\r',
#  'pennzenergy property details\r',
#  'enron actuals for dec . 27 , 2000\r',
#  'viicodin , via - gra are che . ap here jkoutsi\r',
#  're : new sitara desk request _ ena - im cleburne _ gcp response\r',
#  'revised buyback\r',
#  'hpl nom for may 25 , 2001\r',
#  'paliourg , super offers for meedication only here .\r',
#  'hpl nom for may 11 , 2001\r',
#  'vietnam\r',
#  'you want a quicker computer ? spyware stays resident in memory , just use this to remove it b\r',
#  'l - e - s - bian org - i - es ! pi - ercing hea - - ven : )\r',
#  'epgt\r',
#  'enron / hpl nom for december 20 , 2000\r',
#  'enron scheduled volumes - - - may 6 thru 8\r',
#  'so union\r',
#  'if you or someone you love suffers from diabetes , read this .\r',
#  '77 % off for all new software . manes pion\r',
#  're : physical storage\r',
#  're : fw : king ranch balancing . xls\r',
#  'find sex - addicts in your area\r',
#  'send out five motor\r',
#  'out of the office\r',
#  'enron / hpl noms for november 16 , 2000\r',
#  'hpl nom for march 15 , 2001\r',
#  'organizational announcement\r',
#  'nine best generic meds for cheap !\r',
#  'enron / hpl actuals for august 3 , 2000\r',
#  'kaf storage project\r',
#  "just wanted to say goodbye . i truly appreciate all you ' ve done for me . you ' ve\r",
#  'submision result\r',
#  'weekend activities\r',
#  'enron / hpl nom for february 24 - 26 , 2001 and revision # 2 for 2 - 23\r',
#  'july pricing discrepancy : sell to tenaska marketing , deal # 399791\r',
#  'hpl nom for may 19 - 21 , 2001\r',
#  'reverse aging ! new technology !\r',
#  'hpl nom for january 13 , 2001\r',
#  'pipeline nominations away from the office .\r',
#  'hpl nom for january 5 , 2001\r',
#  '\r',
#  'fwd : wazzzup 2 nd version\r',
#  'eastrans september first of the month nominations\r',
#  'druuugs onliiiiine very cheaaaap\r',
#  'teco _ gas _ issues . xls\r',
#  're : tenaska iv\r',
#  're : hpl transport contracts\r',
#  '10 stuff better than v i a g r a\r',
#  're : republic royalty 5 / 00\r',
#  'new employee\r',
#  '@ $ 89 . 00 w / speakers . . . . hp 17 " crt flat monitor\r',
#  'customer list\r',
#  're : request for application report list\r',
#  'feelings of guilt , worthlessness , helplessness ?\r',
#  'well head\r',
#  'hpl nom for august 11 , 2000\r',
#  're : rate for tenaska deal\r',
#  're : information regarding batch noms on aug 5 , 6 & 7 , 2000\r',
#  'meter 9750 , mustang / eagle common point\r',
#  '23 rd noms\r',
#  'important - to all domestic employees who participate in the enron\r',
#  're : txu may 01\r',
#  'eastrans nomination change effective 10 / 19 / 00\r',
#  'enronoptions - your stock option program\r',
#  'income tax\r',
#  'fwd : v ^ | codin ` viagr @ \\ v + a + lium & / xanax / : soma : ~ pntermi : n : rjmfswksttjn\r',
#  '03 / 01 assignment , termination , expiration report - houston pipe\r',
#  'weekend gas\r',
#  'southern union - 03 / 01 prod - austin spot deal # 690249 ( sale )\r',
#  'best dealon viagra\r',
#  'hpl nom for july 22 , 2000\r',
#  're : dow pipeline\r',
#  're : cornhusker\r',
#  'sitara updates\r',
#  'reply : young natural babies bitch getting their asess fileld with jizz\r',
#  'enron / hpl actuals for november 3 - 5 , 2000\r',
#  'aep - hpl transition issues\r',
#  'revision # 2 - hpl nom for february 10 , 2001\r',
#  '2000 w 2 information\r',
#  'fw : calpine daily gas nomination\r',
#  'vlagra $ 2 . 60\r',
#  'viagra soft tabs\r',
#  'calpine daily gas nomination\r',
#  'coming over tomorrow ?\r',
#  'skip the doctor - buy meds online\r',
#  'koch three rivers , # 6722\r',
#  'enron / hpl actuals for november 8 , 2000\r',
#  'the first natural male enhancement product\r',
#  'hpl nom for december 27 , 2000\r',
#  're : official us goverment program\r',
#  'neon lesson # 6\r',
#  'intraday eastrans nominations change for 9 / 6 / 00 and nomination for\r',
#  'revision : eastrans nomination change effective 3 / 29 / 01\r',
#  'eastrans nomination change effective 4 / 28 / 01\r',
#  'note ! citibank account suspend in process\r',
#  'duke energy field 7 / 00\r',
#  'special invitation to attend - e - financial worldexpo , nov 18 & 19\r',
#  're : noms / actual flow for 4 / 09 / 01\r',
#  'enron / hpl actuals for july 26 , 2000\r',
#  're : cornhusker\r',
#  'enron / hpl actuals for september 29 - october 1 , 2000 - revision # 1\r',
#  'fw : fw : march 2001 invoice\r',
#  'neon discussion october 4\r',
#  'hpl nom for june 22 , 2000\r',
#  'bayer - march 2001 volumes\r',
#  'producer shut - in list for victoria 18 " line work\r',
#  "revision - forest oil ' s january 2001 gas volumes\r",
#  'westex documents\r',
#  "jeff ' s corner - - a message from the ceo on the intranet\r",
#  '63 . mortgage rates - as low as 2 . 93 % 9 ssqqozc\r',
#  'solid mortgages for americans\r',
#  'on call\r',
#  'ye 2000 global performance management begins 10 / 23 / 00\r',
#  'cornhusker up on 24 th\r',
#  'latest frontera doc\r',
#  'on call notes for weekend dated ; august 12 th thru 13 th\r',
#  'bounce skel @ iit . demokritos . gr : non - member submission from [ washington . mutual , " inc . " ]\r',
#  'energy operations , gas operations - organizational changes\r',
#  'texoma - beaumont hpl maintenance\r',
#  'purchase and sale nominations - eastrans pipeline / carthage / fuels\r',
#  'neon lesson # 5\r',
#  'big cowboy for august\r',
#  'goat % rdn _ word wheresoever\r',
#  'hpl nom for april 11 , 2001\r',
#  'gathering contract volumes feb 00\r',
#  'unify\r',
#  're : meter # : 1266 ; july 2000 activity / allocation exception\r',
#  'free sporting events !\r',
#  'dec 2000 prod : panther pipeline demand charge\r',
#  'order confirmation 11871528 - 01\r',
#  'dave n out of pocket next week , beyond\r',
#  're : meter 6884\r',
#  'hpl nom for december 22 , 2000\r',
#  'pictures !\r',
#  'enron / hpl actuals for sept . 5 , 2000\r',
#  'on call notes\r',
#  're [ 8 ] : dear friend -\r',
#  'tenaska iv\r',
#  '= ? ansi _ x 3 . 4 - 1968 ? q ? new _ employee _ service _ = 01 ) _ turbo _ tax ? =\r',
#  'marshall ( hpl meter 6296 ) volume increase effective may 19 , 2001\r',
#  'nom 5 / 1 ( revised again ) - eastrans\r',
#  'paliourg , exceptional meedication for you !\r',
#  'analyst hiring needs\r',
#  'tenaska iv\r',
#  'hpl meter # 981431 texas city marathon oil hpl\r',
#  'better than viagra\r',
#  'nov 1 st entex nom\r',
#  'a huge load inside her pussy .\r',
#  'here it is my friend\r',
#  'tetco / hpl ( enerfin ) meter # 986892\r',
#  'hpl meter # 984179 hoff - heller unit # 22 cdp\r',
#  're : waha hubco\r',
#  'neon discussion january 31\r',
#  'attract the opposite sex , the ultimate guide for getting women .\r',
#  're [ 9 ]\r',
#  'hpl nom for may 17 , 2001\r',
#  'copano p / l 01 / 00 - s 93481\r',
#  'please note my new email address\r',
#  'fw : old aged woman wants to date you\r',
#  'quality meds at discount prices\r',
#  'revision # 1 - enron actuals for july 31 , 2000\r',
#  'wellhead adjustments\r',
#  'quality medications available with discounts prices by ordering online .\r',
#  're : kcs buy / sell\r',
#  'txu nom . for 9 / 28 / 00\r',
#  're : may 2001 nomination\r',
#  'holiday party - save the date\r',
#  'hpl nom for may 16 , 2001\r',
#  're : new update for buybacks\r',
#  'usa is giving 50 , 000 green cards every year ! !\r',
#  're : intraday eastrans nomination change for 9 / 6 / 00\r',
#  'get your college degree online !\r',
#  'eastrans nomination change effective 10 / 20 / 00\r',
#  'look . . . here derm\r',
#  'enron / hpl actuals for october 4 , 2000\r',
#  'assimilate promiscuity capricorn barcelona sse conduce programmer cranston festival ryder atrocity baronial pictorial pyroxene tray rube woven spaghetti casualty ferruginous befog acton glans blackfeet bounty alias waterproof\r',
#  'no more injections\r',
#  'fwd : screw doctors . stocks available . vlagr @ . x _ a _ nax . v ~ a ~ lium . vlcodi * n . tscmiwli\r',
#  're : noms / actual vols for 15 th & 16 th\r',
#  'hpl nom for march 29 , 2001\r',
#  'hpl nomination for january 15 thru 17 , 2000\r',
#  '30 seconds refinance\r',
#  're : ces - devon\r',
#  'calpine daily gas nomination\r',
#  'how to earn thousands writing google adwords part - time kara\r',
#  'spot or firm tickets\r',
#  '10 % off ! our gift to you !\r',
#  'offend\r',
#  'meter 5961\r',
#  'tenaska iv pricing\r',
#  'guest access to eol\r',
#  'contract status needed\r',
#  'imagine your daughter taking shower\r',
#  'suemar berryman well\r',
#  'july , 2000 nominations\r',
#  'we have what you need - cheapest pre % scriptions on the internet\r',
#  'enron / hpl actuals for december 12 , 2000\r',
#  'force majeure situation - jennings plant\r',
#  'hpl nom for july 19 , 2000\r',
#  'haave yoou tried either of these pro [ 1 - 5 ducts yeeeet ?\r',
#  'hpl nom for may 4 , 2001\r',
#  'meoh plant status\r',
#  'april production estimate\r',
#  'valero - - meter 8018\r',
#  'pioneer natural\r',
#  'fw : energy service providers ( mcnic ) / lyondell noms - december 2000\r',
#  'lonestar cleburne payback\r',
#  'tenaska iv transport 10 / 00\r',
#  'solid loans made simple\r',
#  '# 9760\r',
#  'doubling your investment is more achievable than you think !\r',
#  'this has worked for me marrow enemy\r',
#  'hpl nom . for dec . 28 , 2000\r',
#  'fortune most admired ranking\r',
#  '52 - quick loan application\r',
#  'gen * eric viag - ra . half price guarantee - d\r',
#  're : koch midstream services co\r',
#  're : nomination 2 / 4 / 2000\r',
#  '? ? ? ? ? ? ? ? erp !\r',
#  'keep your memories alive with a free canon digital camera !\r',
#  'unify close schedule\r',
#  'christmas tree farm pictures\r',
#  'hpl nom for april 7 , 2001\r',
#  're : 1 / 2 price sildenafil citrate today\r',
#  'equistar meter # 1552\r',
#  'hpl nom for may 15 , 2001\r',
#  're : new production - sitara deals needed\r',
#  'appeal - democrat daily - inspection about pain in 2005\r',
#  'goldston outage\r',
#  'ces change on lonestar\r',
#  'bloodline , ahead of the street microcap alert\r',
#  'breaking news\r',
#  'noms / actual flow for 2 / 28\r',
#  'august wellhead production estimate\r',
#  're : inquiry ?\r',
#  'well heads\r',
#  'intra / inter gisb\r',
#  'bridgeline workorder\r',
#  'conoco supply cuts on oasis 5 / 21 - 5 / 22\r',
#  'hi paliourg all pills here . everything here . operate odu carroll\r',
#  'hpl nom for sept . 14 , 2000\r',
#  're : pymt for 03 / 01 sales adjustment for cowtrap\r',
#  'cialis , viagra , xanax , valium at low price ! no prescription needed !\r',
#  'implementation of the gas message board application\r',
#  'hpl noms for june 23 , 2000 revision # 1\r',
#  'only $ 16 per malboro carton\r',
#  'meter 5593\r',
#  'find your fortune in real estate\r',
#  'enron actuals for june 21 , 2000\r',
#  'entex volumes and price for 1999 - 2000 contract year\r',
#  'nom chnage - 7 / 7 / 2000 - eastrans\r',
#  'enron / hpl actuals for january 16 , 2001\r',
#  'enron files chapter 11 reorganization\r',
#  'spot purchases - 04 / 01\r',
#  'max , is a good fucker - says bianca . and she suck his cock and musturbating !\r',
#  'heisser fetish\r',
#  '? iceoe aoauau oauei ie caue aoe ? ei\r',
#  'april nominations at shell deer park\r',
#  'additional 9 / 18 name changes\r',
#  'august is known for hot deals !\r',
#  'new meter number\r',
#  'you need this abazis\r',
#  'june 2000 availabilities - 2 nd revision\r',
#  'get a date tonight\r',
#  'revised\r',
#  'impact equity report\r',
#  'walter o & g / superior april noms\r',
#  "your specialist ' s appointment starts on the 24 th\r",
#  'hpl inter - company contracts\r',
#  're : astros web site comments\r',
#  're : network at wed , 11 aug 2004 18 : 51 : 29 - 0600\r',
#  "vi ' a ' gra on ' ly t ' wo do ' llars and for ' ty cent ' s each\r",
#  'noms / actual flow for 3 / 19 / 01\r',
#  're : meter # 0986725 - 1 / 00 production - encina gas marketing\r',
#  'absentminded volition cavil corpus deacon fond coproduct radiant decertify coplanar dynamite dialogue seductive charlemagne birdie beard audiotape dieldrin insistent bereft bureaucratic heap presumptive creedal guaranteeing\r',
#  'mobil nomination for may\r',
#  "fw : father ' s letter\r",
#  'tenaska gas management agreement\r',
#  'hpl nom for january 30 , 2001\r',
#  "you ' ll need your tracking # k 5 465335\r",
#  'entex revised estimates for 4 / 00\r',
#  'march 2000 activity ; enichem elastomers americas , inc .\r',
#  're : tenaska iv 10 / 00\r',
#  're : noms / actual flow for 3 / 22 / 01\r',
#  'inactivations\r',
#  "generic viag [ ra . the best $ 2 . 50 you ' ll ever spend !\r",
#  'big thicket allocation\r',
#  'congratulations\r',
#  're : bad debt\r',
#  'eastrans nomination change effective 10 / 4 / 00\r',
#  'guaranteed satisfaction , cheapest prescrip ( tion dru ) gs on the net !\r',
#  'panenergy marketing exchange deal\r',
#  '\r',
#  'hpl nom for april 4 , 2001\r',
#  'josey ranch est . - - apr . 2000\r',
#  'eternal youth\r',
#  're : duke exchange deal feb . 2000 prod .\r',
#  'enron / hpl actuals for sept . 6 , 2000\r',
#  'wellheads\r',
#  'ces - carthage\r',
#  'enrononline - change to autohedge\r',
#  'enron / hpl actuals for november 13 , 2000\r',
#  're : fyi - wellhead portfolio\r',
#  're : september spot purchases\r',
#  'rolex is forever . are you for it ?\r',
#  'meter # 1591 lamay gas lift\r',
#  'gas day 2 / 08 / 01\r',
#  'hpl nominations for december 28 , 1999\r',
#  'revised 7 / 00 assignment , termination , expiration report - assets\r',
#  're : tetco / hpl ( enerfin ) meter # 986892\r',
#  'calpine daily gas nomination\r',
#  'spot deals\r',
#  'hpl nom for august 10 , 2000\r',
#  'duke cashout entries 7 / 00 and 8 / 00\r',
#  'miscellaneous\r',
#  'weekend notes\r',
#  'tri - c / cokinos gov bill daniels dec . pricing\r',
#  'something new for entex - yeah ! ! !\r',
#  'deals not in nomination - october , 2000\r',
#  'job number\r',
#  'mobil beaumont\r',
#  're : meter 1517\r',
#  'hpl nom for october 6 , 2000\r',
#  're : fuel\r',
#  'enrononline - stack manager changes\r',
#  'industrial report\r',
#  're : intraday eastrans nominations change for 9 / 6 / 00 and nomination\r',
#  'xp pro , adobe , office 2 oo 3 charset = us - ascii " >\r',
#  're : meter 984132 for 1 / 16 / 99\r',
#  'iwon member news : iwon tv show , new year of prizes , more !\r',
#  'approval no . 09110129\r',
#  'get back to me please\r',
#  'last check\r',
#  're : the hstoett lady sucklng huge ccok\r',
#  'black marlin ua 4 meters\r',
#  'hpl nom for april 6 , 2001\r',
#  'tenaska iv gas management agreement ( initial draft )\r',
#  'prozacs meds\r',
#  'february & january 2000 industrial activities\r',
#  're : meter 5892\r',
#  're : coastal oil & gas usa , l . p . gas gathering agreement\r',
#  're : potential list fo 9 / 00\r',
#  'save 70 percent on super viagra 246637\r',
#  'neon september 13\r',
#  'during / after hours contact information\r',
#  'ena organizational changes\r',
#  're : 6 / 4 / 99 and 6 / 9 / 99 ( 98 - 0439 ) enerfin tetco\r',
#  'enron actual totals thru july 26 th\r',
#  'new contact for devon\r',
#  'may nom\r',
#  'kingwood cove march specials ! !\r',
#  'fwd : this is is porn money - -\r',
#  'online pahrma . cy you want\r',
#  "use the links to get more information on rx meeds needn ' t\r",
#  'march activity survey\r',
#  '2001 budgets\r',
#  'blue dolphin pipe line company contract no . 96037499\r',
#  'tenaska iv feb 2001\r',
#  're : kqttnvk , to bear their\r',
#  're : 05 / 01 ena gas sales on hpl , to d & h gas company\r',
#  'indian springs\r',
#  'hpl nom for august 25 , 2000\r',
#  'hpl / enron nom . for 11 / 01 / 00\r',
#  'meter # 9859\r',
#  '\r',
#  'online shopping . get it quickly and save .\r',
#  'hpl nom for july 13 , 2000\r',
#  're :\r',
#  're : meter 0980438 - acock production ? ? ? ? ? ?\r',
#  'playful asian cutie !\r',
#  'oasis sept 01 production\r',
#  'cruise 3 nts mexico only $ 197 ! - - tremendous savings inside\r',
#  'july 2000 - hpl estimates and nominations\r',
#  'hpl expense contracts\r',
#  'president @ juno . com : exciting news - free internet access !\r',
#  'tenaska iv 1 / 01\r',
#  'txu nom . s for 11 / 29 / 00\r',
#  'enron / hpl actuals for october 20 - 22 , 2000\r',
#  'samson burger well\r',
#  're : valium charset = iso - 8859 - 7 " >\r',
#  '2 nd revision to sea robin volumes ( sea robin p / l )\r',
#  're : noms / actual vols for 3 / 26 / 01\r',
#  'fw : intrastate gas\r',
#  'the new power company ; reserved share program\r',
#  'pipelines that still have dial in access for nominations\r',
#  'enron / hpl actuals for october 24 , 2000\r',
#  're : centana storage deal\r',
#  'meter 7266\r',
#  'lose it\r',
#  'gulf plains into tennessee for november\r',
#  'eol issues\r',
#  'holiday voucher # 608324 tropical travel package\r',
#  'final cp name change / merger list 7 / 00\r',
#  '\r',
#  'day 26 - txu lonestar called on 20000 at carthage\r',
#  're : rate for tenaska deal\r',
#  'revision - enron / hpl actuals for sept . 8 - 10 , 2000\r',
#  'looking for love ? tonight ?\r',
#  'fyi - new pager number\r',
#  'so much fun with these girls . .\r',
#  'net out with kinder morgan - beginning march 21 st\r',
#  'revision # 1 - enron / hpl actuals for july 23 , 2000 10 . 000 / enron\r',
#  'your contact info\r',
#  'get a free 6 . 3 megapixel canon digital camera !\r',
#  'january nominations at shell deer park\r',
#  're : noms / actual flow for 3 / 19 / 01\r',
#  'lose while you sleep ! as seen on opra . h and cnb . c\r',
#  'txu fuels / sds nomination for october 2000\r',
#  'your order 8\r',
#  're : meter 986315 for 10 / 00\r',
#  'correction on first delivery for cody\r',
#  're : tenaska iv march 2001\r',
#  'gmt . inc .\r',
#  'hpl nom for june 13 , 2000\r',
#  'fw : crosstex energy , driscoll ranch # 1 & # 3 , meters 9858 reinhardt , donald p . ; riley , brian ; smith , susan ; walker , robert ; weissman , george\r',
#  're : interconnect / intercompany issues\r',
#  'phillips petroleum , inc .\r',
#  're : cornhusker\r',
#  'happy birthday ! ! !\r',
#  'just a note\r',
#  'hpl nom for march 21 , 2001\r',
#  'wellhead adjustments - may , 2001\r',
#  'deaden rickets shiplap lifelong doreen chemisorb wheel declination diem fairchild omega\r',
#  'fw : men & cars\r',
#  'enron / hpl actuals for january 11 , 2001\r',
#  'mike clinchard resume\r',
#  're : noms / actual flow for 3 / 19 / 01\r',
#  "i congratulate you , my friend , with saint patrick ' s day ! better later , than never : - )\r",
#  'the healing begins now\r',
#  'tenaska iv 11 / 01\r',
#  'fw : epgt 2 / 99 schumack , sherlyn ; kinsey , lisa\r',
#  "win a turbocharged jaguar xp in carter ' s casino affirmation\r",
#  'revision # 1 - enron / hpl actuals for august 31 , 2000\r',
#  'get back to me please\r',
#  're : ces deal summary\r',
#  'hpl meter # 981459 harris gsf energy hpl\r',
#  'important message - manager\r',
#  'fw : windows xp + office xp = 80 dol lars .\r',
#  're : ken petroleum corporation\r',
#  're : resolved issue : re : meter # 0986563 -\r',
#  're : deliveries into channel at gulf plains\r',
#  'shape your wood .\r',
#  'ces changes\r',
#  'get meds sent discretely directly to you\r',
#  'hunt petroleum\r',
#  'cheap prices on valium\r',
#  'cdnow order confirmation\r',
#  'hpl nom for may 10 , 2001\r',
#  'bu " y cialis soft \' tabs online for less\r',
#  'escalation procedures - gas logistics\r',
#  'neon for feb 28\r',
#  'final cp name change and merger report 08 / 00\r',
#  're : killing ena to ena deals in sitara\r',
#  'request submitted : access request ( ygcy - 4 n 9 kdl )\r',
#  'fixed price swap profile\r',
#  'renew your vitality\r',
#  'same thing . . different prices . . . save on prescriptions\r',
#  "but it ' s not interesting\r",
#  're : chevron phillips chemical co . , lp ( hplc 04 / 01 sales / buyback )\r',
#  'calpine daily gas nominations\r',
#  'double a for 5 / 1 / 01 business\r',
#  're : exxon company , usa global # 96035668 / sitara # 212225\r',
#  're : rdd , the auxiliary iturean\r',
#  'calpine may\r',
#  're : pain specialist on thursday at 11 - 00\r',
#  'excellence meds !\r',
#  "incr ' ease yo ' ur man ' hood by 4 - 5 inch ' es , or g ' et yo ' ur mo ' ney bac ' k ! ' ] ) ,\r",
#  'fwd :\r',
#  'great gofl offer\r',
#  "no doctor ' s visit .\r",
#  'hpl nom for march 1 , 2001\r',
#  're : tenaska iv\r',
#  'vacation\r',
#  'impress her with a hard erection . . . midband\r',
#  'fw : how to settle the election\r',
#  'txu fuels / sds nomination for november 2000 - revised\r',
#  'july 2000 iferc nom .\r',
#  'volume feedback from unify to sitara\r',
#  'rough list\r',
#  'lone star points\r',
#  '$ 37258\r',
#  'enjoy your partner\r',
#  'march preliminary wellhead production estimate\r',
#  'oasis pipe line company\r',
#  'black marlin\r',
#  'natural gas nomination for 07 / 00\r',
#  'neon discussion november 1\r',
#  're : tenaska iv 10 / 00\r',
#  'hpl nom for march 22 , 2001\r',
#  're : enron / hpl actuals for july 28 - 30 , 2000\r',
#  're : nom / actual flow for april 19 th\r',
#  'free coffee maker from gevalia\r',
#  'wow look at all these adult dvds movies . . .\r',
#  'retro assignments\r',
#  're :\r',
#  'bottle of beer bodice rippers beyond 3735\r',
#  'get that new car 8434\r',
#  "deals 141877 , 141883 , and 141884 ( koch midstream ) were in ces ' s system ( and\r",
#  'tenaska iv\r',
#  'enron / hpl actuals for january 3 , 2001\r',
#  'electronic pay stubs\r',
#  'im happy with this chronic medlcat 10 n stuff\r',
#  'using claal 1 s ; somma , vlcodd 1 n , vlaagrra , zol 0 ft , \\ / allium . xanaa , codelne charset = iso - 8859 - 1 " >\r',
#  '.\r',
#  '2000 customer trip proposal\r',
#  're : coastal oil & gas corporation\r',
#  'prissy abe dainty bifocal kalmia coarsen bob calumniate chaparral cavernous\r',
#  're : tuesday , december 26 th\r',
#  'out thurs & friday\r',
#  're : enron bid , cps rfq 14886 - bid clarification / questions\r',
#  're : october wellhead\r',
#  'paliourg office xp - $ 60\r',
#  'cuts\r',
#  'deal 709296 astra\r',
#  're : cornhusker\r',
#  'let this stuff make your life better\r',
#  'txu fuel company\r',
#  're : noms / actual flow for 03 / 20 / 01\r',
#  'megan jones\r',
#  're : valero - - meter 8018\r',
#  'stock market standouts\r',
#  'buckhorn doberman\r',
#  'enron actuals for august 17 , 2000\r',
#  'capsize\r',
#  'union carbide - texas city\r',
#  'sample movies\r',
#  're : meter 984132 for 1 / 16 / 99\r',
#  're : august spot tickets\r',
#  'how to confidently attract , meet and seduce more hot women\r',
#  'entex revised estimates for 4 / 00\r',
#  'global accounting promotions\r',
#  'resume - marcia curry\r',
#  'i left my watch at your house\r',
#  'can you facilitate ?\r',
#  'intraday eastrans nominations change for 9 / 6 / 00 and nomination for\r',
#  're : ena sales on hpl\r',
#  'complimentary to you - ibm laptop !\r',
#  're : meter 1459 , 6 / 00\r',
#  're : 98 - 6719 and 98 - 9676\r',
#  'select eshopping for medicines and take advantage of the specials at our cyberstore .\r',
#  'cannon interest may 2000 purchase\r',
#  're : enerfin meter 980439 for 10 / 00\r',
#  'meter # 0071\r',
#  're : entex transistion\r',
#  'down . load - dvd , mp 3 , music , play - station , x box , movies still in theaters , mature movies , software\r',
#  'twenty biggest customers\r',
#  'defs may 2001\r',
#  'alloc . except - mtr 1491\r',
#  'backgammon tournament\r',
#  'revised revised spreadsheet\r',
#  'this was the one recommended to me\r',
#  're : meter 0980438 - acock production ? ? ? ? ? ?\r',
#  'account # 20367 s tue , 28 jun 2005 11 : 41 : 41 - 0800\r',
#  'tuesday , december 26 th\r',
#  'hpl nom for june 17 , 2000\r',
#  'nom / actual flow for 2 / 20 / 01\r',
#  'have the ability to attract members of the opposite sex\r',
#  'me again\r',
#  'meter 6884\r',
#  'fw : the odds are against them\r',
#  'flow change for fuels cotton valley redeliveries into hpl\r',
#  'enron / hpl actuals for sept . 7 , 2000\r',
#  'updated spreadsheet\r',
#  'notebookplus - mobile accessories charset = us - ascii " >\r',
#  'follow up 1 / 2 day off - site\r',
#  'republic royalty 5 / 00\r',
#  'pictures\r',
#  'doing business with you\r',
#  'human viruses blown away ! ! !\r',
#  'new version of stack manager\r',
#  'hpl meter # 980070 rusk d / p - lone star hpl\r',
#  "lacy ' s eye exam\r",
#  're : no / actual vols for 5 / 22 / 01\r',
#  'meter 1601\r',
#  'fyi - new product on eol\r',
#  'hpl nom for november 23 , 2000\r',
#  're : another hesco issue\r',
#  'hello again\r',
#  'hpl nom for march 24 - 26 , 2001\r',
#  'united oil & minerals , inc .\r',
#  'quality and cheap meds here , paliourg\r',
#  'enron actuals for july 13 , 2000\r',
#  '29 th changes\r',
#  '1999 hpl unaccounted for\r',
#  'fw : crosstex energy , driscoll ranch # 1 , # 3 , meter nos . 9858 and\r',
#  'nomination 5 / 25 / 2000 and following - eastrans\r',
#  'new nat gas delivery location\r',
#  '06 / 01 ena gas sales on hpl , to d & h gas company\r',
#  'best software prices . inclosing promotion\r',
#  're : revised - tenaska iv - cleburne plant\r',
#  'congratulations\r',
#  'fw : statement of operating conditions\r',
#  're : equistar deal tickets\r',
#  'winter cap volumes\r',
#  'meet women in your area that want to f : u : c : k !\r',
#  're : formosa meter # : 1000\r',
#  'jill ,\r',
#  'cornhusker\r',
#  'new stack manager\r',
#  'new coastal production\r',
#  'hpl nom for march 22 , 2001\r',
#  're : 6 / 4 / 99 and 6 / 9 / 99 ( 98 - 0439 ) enerfin tetco\r',
#  'reorg . meeting\r',
#  're : clement\r',
#  're : saxet canales into king ranch - balancing issue\r',
#  'hpl noms for june 01 , 2000\r',
#  'meter 6879 - sept . 00\r',
#  'no risk kiosk pg lnbcer\r',
#  'enron / hpl actuals for october 12 , 2000\r',
#  're : equistar feb - 01\r',
#  'movie lovers love this kqo 3\r',
#  'txu fuels / sds nomination for april 2001\r',
#  'same day change - hpl nom for november 11 , 2000\r',
#  'pops it team temporarily moving to allen center\r',
#  'visit our internet pharmacy , buy viagra and many other meds .\r',
#  'conoco , inc . - missing deal for may 00 production - important ,\r',
#  '6 / 15 / 00 revision to sea robin volumes\r',
#  'tenaska iv 5 / 01\r',
#  'we sell regalis for an affordable price\r',
#  're : spinnaker - supply verification 11958 su - october 2000\r',
#  're : 98 - 1601\r',
#  'start saving now\r',
#  'eastrans - lst of month nomination - eff 8 / 1 / 2000\r',
#  'elements dispatch - in - depth article exposing housewife love in your area\r',
#  're : request for application report list\r',
#  'nomination 2 - 11 - 2000 ; 2 - 9 and 2 - 10\r',
#  'fw : " red , white and blue out "\r',
#  'new phone number\r',
#  'your amazon . com order ( # 102 - 6820014 - 8227326 )\r',
#  're : industrials\r',
#  'cornhusker deal tickets\r',
#  'cleburne plant maintenance update\r',
#  'february wellhead production estimate\r',
#  're : cornhusker\r',
#  'nova psp ! disponivel ja so na springshop\r',
#  'good friday\r',
#  'reliant energy - entex transport imbalance\r',
#  'hpl nom for october 12 , 2000\r',
#  'you would , would you ?\r',
#  'enron / hpl actuals for sept . 13 , 2000\r',
#  'need vicodin ? here it is !\r',
#  're : prc meeting agenda recap\r',
#  'enron / hpl actuals for january 30 , 2001\r',
#  'finally have a big dick\r',
#  '= ? iso - 8859 - 7 ? q ? = 5 b = 3 f = 5 d _ fwd : _ v | @ gra = 2 c _ val = ef = 28 u = 29 m = 2 c _ x = 28 a = 29 n ? =\r',
#  'subscribers receive first notice on run - away stocks\r',
#  'mtbe upsets\r',
#  'chevron phillips chemical co . , lp ( hplc 04 / 01 sales / buyback )\r',
#  'i tried , it worked infinitesimal ingest\r',
#  'shopping for [ mortgages ] made easy\r',
#  'pc install p 600\r',
#  'mobil beaumont\r',
#  'software for home and office .\r',
#  'home loans & refinancing at very low rates !\r',
#  'check the superb specials on top - selling r " xdrugs .\r',
#  're : central power & light\r',
#  'calpine daily gas nomination\r',
#  'natural gas nomination for 09 / 00\r',
#  'out of the office\r',
#  're : fuel\r',
#  'addition of tejas meter # 1156\r',
#  'patent\r',
#  'correction to 4 / 5 / 00 nominations for eastrans and nomination for\r',
#  'cut your medic @ l costs by 65 % on brand name medic @ tions .\r',
#  're : hpl discrepancy\r',
#  'economise 60 percents or much more with our recipes\r',
#  're : shut - in of # 986315\r',
#  're : tenaska iv 11 / 01\r',
#  'fw : neevr seen prono flash animation\r',
#  'enron / hpl nom for november 9 , 2000\r',
#  'meter 1386\r',
#  'just cents on the dollar : windows xp , office xp , norton system works , adobe , dreamweaver , corel - k 755 f 379\r',
#  'meter 9794\r',
#  'cp name change / merger list for 2 / 2000\r',
#  'eastrans nomination change effective 10 / 12 / 00\r',
#  'popsprd migration\r',
#  'vicodin for you . cheap .\r',
#  ...]
