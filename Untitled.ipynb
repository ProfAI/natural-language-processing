# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
sentence = "This is a first sentence for our example!"

# %%
doc = nlp(sentence)

# %%
for token in doc:
    print(str(token)+" : "+str(token.pos_))
# Out:
# This : PRON
# is : AUX
# a : DET
# first : ADJ
# sentence : NOUN
# for : ADP
# our : PRON
# example : NOUN
# ! : PUNCT

# %%
sentence = "NETHIC: A system for automatic text classification using neural networks and hierarchical taxonomies. This paper presents NETHIC, a software system for the automatic classification of textual documents based on hierarchical taxonomies and artificial neural networks. This approach combines the advantages of highly-structured hierarchies of textual labels with the versatility and scalability of neural networks, thus bringing about a textual classifier that displays high levels of performance in terms of both effectiveness and efficiency. The system has first been tested as a general-purpose classifier on a generic document corpus, and then applied to the specific domain tackled by DANTE, a European project that is meant to address criminal and terrorist-related online contents, showing consistent results across both application domains."
doc = nlp(sentence)
for token in doc:
    print(str(token)+" : "+str(token.pos_))
# Out:
# NETHIC : NOUN
# : : PUNCT
# A : DET
# system : NOUN
# for : ADP
# automatic : ADJ
# text : NOUN
# classification : NOUN
# using : VERB
# neural : ADJ
# networks : NOUN
# and : CCONJ
# hierarchical : ADJ
# taxonomies : NOUN
# . : PUNCT
# This : DET
# paper : NOUN
# presents : VERB
# NETHIC : NOUN
# , : PUNCT
# a : DET
# software : NOUN
# system : NOUN
# for : ADP
# the : DET
# automatic : ADJ
# classification : NOUN
# of : ADP
# textual : ADJ
# documents : NOUN
# based : VERB
# on : ADP
# hierarchical : ADJ
# taxonomies : NOUN
# and : CCONJ
# artificial : ADJ
# neural : ADJ
# networks : NOUN
# . : PUNCT
# This : DET
# approach : NOUN
# combines : VERB
# the : DET
# advantages : NOUN
# of : ADP
# highly : ADV
# - : PUNCT
# structured : VERB
# hierarchies : NOUN
# of : ADP
# textual : ADJ
# labels : NOUN
# with : ADP
# the : DET
# versatility : NOUN
# and : CCONJ
# scalability : NOUN
# of : ADP
# neural : ADJ
# networks : NOUN
# , : PUNCT
# thus : ADV
# bringing : VERB
# about : ADP
# a : DET
# textual : ADJ
# classifier : NOUN
# that : PRON
# displays : VERB
# high : ADJ
# levels : NOUN
# of : ADP
# performance : NOUN
# in : ADP
# terms : NOUN
# of : ADP
# both : DET
# effectiveness : NOUN
# and : CCONJ
# efficiency : NOUN
# . : PUNCT
# The : DET
# system : NOUN
# has : AUX
# first : ADV
# been : AUX
# tested : VERB
# as : ADP
# a : DET
# general : ADJ
# - : PUNCT
# purpose : NOUN
# classifier : NOUN
# on : ADP
# a : DET
# generic : ADJ
# document : NOUN
# corpus : NOUN
# , : PUNCT
# and : CCONJ
# then : ADV
# applied : VERB
# to : ADP
# the : DET
# specific : ADJ
# domain : NOUN
# tackled : VERB
# by : ADP
# DANTE : PROPN
# , : PUNCT
# a : DET
# European : ADJ
# project : NOUN
# that : PRON
# is : AUX
# meant : VERB
# to : PART
# address : VERB
# criminal : ADJ
# and : CCONJ
# terrorist : NOUN
# - : PUNCT
# related : VERB
# online : ADJ
# contents : NOUN
# , : PUNCT
# showing : VERB
# consistent : ADJ
# results : NOUN
# across : ADP
# both : DET
# application : NOUN
# domains : NOUN
# . : PUNCT

# %% [markdown]
# ## NER

# %%
sentence = "Amazon is one of the 3 best companies for ecommerce in Europe"

doc = nlp(sentence)

for token in doc:
    print(str(token) + " : " + (token.ent_type_))
# Out:
# Amazon : ORG
# is :
# one : CARDINAL
# of :
# the :
# 3 : CARDINAL
# best :
# companies :
# for :
# ecommerce :
# in :
# Europe : LOC

# %%
import spacy.displacy as displacy

# %%
displacy.serve(doc, style="ent")
# Out:
# C:\Users\Luigi\anaconda3\envs\professionAI\lib\site-packages\spacy\displacy\__init__.py:103: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  best companies for ecommerce in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
sentence = "The White House is the official residence and workplace of the president of the United States. It is located at 1600 Pennsylvania Avenue NW in Washington, D.C., and has been the residence of every U.S. president since John Adams in 1800. The term White House is often used as a metonym for the president and his advisers. "

# %%
doc = nlp(sentence)
for token in doc:
    print(str(token)+ " : "+ str(token.ent_type_))
# Out:
# The : ORG
# White : ORG
# House : ORG
# is :
# the :
# official :
# residence :
# and :
# workplace :
# of :
# the :
# president :
# of :
# the : GPE
# United : GPE
# States : GPE
# . :
# It :
# is :
# located :
# at :
# 1600 : DATE
# Pennsylvania : FAC
# Avenue : FAC
# NW : FAC
# in :
# Washington : GPE
# , :
# D.C. : GPE
# , :
# and :
# has :
# been :
# the :
# residence :
# of :
# every :
# U.S. : GPE
# president :
# since :
# John : PERSON
# Adams : PERSON
# in :
# 1800 : DATE
# . :
# The :
# term :
# White : ORG
# House : ORG
# is :
# often :
# used :
# as :
# a :
# metonym :
# for :
# the :
# president :
# and :
# his :
# advisers :
# . :

# %%
displacy.serve(doc,style="ent")
# Out:
# C:\Users\Luigi\anaconda3\envs\professionAI\lib\site-packages\spacy\displacy\__init__.py:103: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The White House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is the official residence and workplace of the president of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . It is located at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1600
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pennsylvania Avenue NW
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Washington
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     D.C.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and has been the residence of every
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  president since
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John Adams
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1800
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The term
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     White House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is often used as a metonym for the president and his advisers. </div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# ## ESERCITAZIONE
# ### Utilizzando il dataset pulito 20newsgroup, prova ad estrarre per ogni documento tutte le ORGANIZZAZIONI (ORG) le date (DATE), le persone (PERSON) e i luoghi (LOC)

# %%
import pandas

# %%
dataset = pandas.read_csv("datasets/Lezione_1-data_cleaning/dataset_cleaned.csv")

# %%
dataset = dataset['data']

# %%
len(dataset)
# Out:
# 11314

# %%
def entities(sentence):
    to_return = {"ORG":[], "DATE":[], "PERSON":[], "LOC":[]}
    doc = nlp(sentence)
    for token in doc:
        if str(token.ent_type_) in ["ORG","DATE","PERSON","LOC"]:
            to_return[str(token.ent_type_)].append(str(token))
    
    return to_return

# %%
for sentence in dataset[:100]:
    print("---------------------------------------")
    print(entities(sentence))
# Out:
# ---------------------------------------
# {'ORG': ['umd', 'edu', 'organization', 'university', 'maryland'], 'DATE': [], 'PERSON': ['-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['u', 'washington', 'edu', 'u', 'washington'], 'DATE': ['next', 'two', 'day'], 'PERSON': ['guykuo', 'carson', 'kuo', '-PRON-', 'kuo'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['ec', 'ecn', '-PRON-'], 'DATE': [], 'PERSON': ['thomas', 'e', 'willis', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'tom', 'willis', 'twillis', 'f', 'w', 'nietzsche'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['organization', 'harris', 'computer', 'systems', 'csd', 'harris'], 'DATE': [], 'PERSON': ['jgreen', 'amber', 'joe', 'green', 'subject', 'weitek', '-PRON-', '-PRON-', 'weitek', 'joe', 'green', 'harris', 'corporation'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['cfa', 'harvard'], 'DATE': [], 'PERSON': ['jcm', 'head', 'jonathan', 'mcdowell', 'tom', 'baker', 'article', 'cjlwx', 'h', ' ', '-PRON-', 'tom', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'jonathan'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': ['thousand', 'people', 'kill', 'year', 'today'], 'PERSON': ['douglas', 'subject', 'reword', 'second', 'douglas', 'write', 'qvv', 'john', 'lawrence', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'sarah', 'brady', '-PRON-', '-PRON-', '-PRON-', 'john', 'lawrence', 'rutledge', '-PRON-', 'believe', '-PRON-', 'douglas', 'foxvog'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['bmdelane', 'quads', 'uchicago', 'organization', 'university', 'chicago', 'line', 'hmmm', 'news', 'brian'], 'DATE': ['last', 'september'], 'PERSON': ['astrocytoma', 'debra', 'sharon'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['-PRON-', 'mac', 'stanford', 'edu', '    ', 'mac', 'mac', 'ibm', 'mac', 'ibm', 'mac', 'ibm'], 'DATE': ['april', '   '], 'PERSON': ['bgrubb', 'dante', 'nmsu', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['organization', 'university', 'northern', 'iowa', 'ps', 'please', 'e', '-PRON-'], 'DATE': [], 'PERSON': [], 'LOC': []}
# ---------------------------------------
# {'ORG': ['kerr', 'ux', 'cso', 'uiuc', 'edu', 'stan', 'kerr', '-PRON-', 'u', 'illinois', 'urbana', 'phone'], 'DATE': [], 'PERSON': ['-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['-PRON-'], 'DATE': [], 'PERSON': ['irwin', 'cmptrc', 'lonestar', 'org', 'irwin', 'arnstein', '-PRON-', 'computrac', 'inc', 'richardson', 'tx', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'computrac', 'richardson', 'tx', 'irwin', 'cmptrc', 'lonestar'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['james', 'owens', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['hewlett', 'packard', 'fort', 'hewlett', 'packard', 'rodc'], 'DATE': [], 'PERSON': [], 'LOC': []}
# ---------------------------------------
# {'ORG': ['tm', 'lerc', 'nasa', 'new', 'york', 'times', 'elv'], 'DATE': ['today', 'yesterday', 'today', 'lerc'], 'PERSON': ['dbm', 'tm', 'lerc', 'nasa', 'joe', 'shea', 'committee', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'propulsion', 'module', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['jllee', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['kmr', 'po', 'cwru', 'keith', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['ab', 'nova'], 'DATE': [], 'PERSON': ['edu', 'allen', 'martin', 'preston', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['kevin', 'louisiana', 'tech', 'university', 'state', 'farm', 'insurance', 'motorola', 'u', 'oklahoma', 'uokmax', 'ecn', 'uoknor', 'toyota', 'toyota', 'reason', 'porsche', 'honda', 'toyota', 'k', 'personal', 'k', 'total', 'k', 'property'], 'DATE': ['september', 'last', 'year', 'last', ' ', 'month', 'roughly', ' ', 'year', 'year', 'ago', 'year', 'monthly', 'year', 'month', 'less', ' ', 'year'], 'PERSON': ['cpkjp', 'vm', 'cc', 'latech', '-PRON-', '-PRON-', '-PRON-', 'steve', 'flynn', 'kevin', '-PRON-', '-PRON-', 'dan', 'dans', '-PRON-', '-PRON-', 'james', 'james', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'goldberg', 'oasys', 'albert', 'einstein', ' ', '-PRON-', '-PRON-', 'robert', 'robert', 'stack', 'vijay', 'vijay', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['ritley', 'uiucmrl', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['-PRON-', 'telnet', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['california', 'institute', 'caltech', 'edu', 'livesey', 'solntze', 'sgi', 'keith'], 'DATE': [], 'PERSON': ['keith', 'cco', 'caltech', 'keith', 'jon', 'livesey', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['unc', 'edu', 'scott', 'marks', 'launchpad', 'unc', 'edu', 'scott', 'marks'], 'DATE': [], 'PERSON': ['gary', 'leung', 'mike', 'ramsey', '-PRON-', '-PRON-', 'mike', 'foligno', '-PRON-', 'chicago', 'steve', 'thomas', 'ed', 'olcyzk', 'darryl', 'sittler', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['usa', 'line', ' ', 'focus', 'engineering', 'scien', 'tific', 'application', '-PRON-'], 'DATE': [], 'PERSON': ['andy', 'freeman', 'joe', 'doll', 'xt', 'ps', '-PRON-', '-PRON-', 'catalog', 'e', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'ton', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['csypher', 'uafhp', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['nodine', 'lcs', 'mit', 'edu', 'mark', 'h', 'nodine'], 'DATE': [], 'PERSON': ['-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['kenneth', 'hinckley', 'organization', 'university', 'virginia', 'ibm', 'virginia', 'edu', 'university', 'virginia', 'neurosurgical'], 'DATE': [], 'PERSON': ['kenneth', 'hinckley', 'ken', 'hinckley'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['excerpt', 'netnews'], 'DATE': [], 'PERSON': ['john', 'nagle', 'alan', 'martin', 'andrew', 'cmu', 'edu', '-PRON-', '-PRON-', '-PRON-', 'john', 'nagle'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['al', 'organization', 'university', 'keyword', 'game', 'length'], 'DATE': [], 'PERSON': ['r', 'joplin', 'biosci', 'arizona', 'doug', 'roberts', 'joplin', 'biosci', 'doug', 'roberts', 'ken', 'hill'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['cleveland', 'freenet', '-PRON-'], 'DATE': [], 'PERSON': ['jonh', 'david', 'wheaton', 'jonathan', 'hayward', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'jonathan', 'hayward'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['sony', 'sony', '-PRON-', 'sony'], 'DATE': [], 'PERSON': ['michael', 'r', 'hartman', 'ames', 'ia', 'kenneth', 'dwayne', 'ray', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'michael'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['-PRON-'], 'DATE': [], 'PERSON': ['-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'pat', 'churchill'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['british', 'columbia'], 'DATE': ['past', 'year'], 'PERSON': ['xandor', 'john', 'gilbert'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['columbia', 'columbia', 'edu', 'reply', 'columbia', 'columbia', 'university', 'harvard', '-PRON-', 'fatah'], 'DATE': ['month', 'january', 'mid', 'march', 'jewish', 'last', 'week'], 'PERSON': ['amir', 'rosenblatt', 'amir', 'rosenblatt', 'organization', 'adam', 'shostack', 'zbib', 'bnr', 'hagana', '-PRON-', '-PRON-', '-PRON-', 'yehiam', 'western', 'memoriam', 'time', '-PRON-', '-PRON-', 'murmur', 'amir'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['joe', 'cipale', '-PRON-', 'joe'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': ['last', 'year'], 'PERSON': ['keith', 'keller', 'john', 'vanbiesbrouck', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'ed', 'belfour', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['joe', 'ehrlich', 'subject', 'bmw', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['jarthur', 'claremont', 'eli', 'brandt', 'congress', 'pgp', ' ', 'key', 'eli', 'ebrandt', 'jarthur', 'claremont'], 'DATE': [], 'PERSON': ['-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'clinton', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'amanda'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['nec', 'nec', 'systems', 'laboratory', 'inc', 'distribution', 'usa', 'line', ' ', 'scumbag', 'insurance', 'scum', 'insurance', 'nec'], 'DATE': ['today'], 'PERSON': ['chris', 'behanna', 'tom', 'coradeschi', 'write', 'article', 'apr', '  ', 'richard', 'pierson', '-PRON-', '-PRON-', 'bzzzt', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['boeing'], 'DATE': [], 'PERSON': ['rick', 'bressler', '-PRON-', 'american', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'mouth', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['berkeley', 'node', 'net', 'yale', 'yale', '-PRON-'], 'DATE': [], 'PERSON': ['sean', 'garrison', 'krueger', 'helium', '-PRON-', 'funny', 'roger', 'lustig', 'point', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['-PRON-'], 'DATE': [], 'PERSON': ['zod', 'zod'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['ab', 'cleveland', 'freenet', 'western', 'reserve', 'university', 'cleveland', 'ohio', 'usa'], 'DATE': [], 'PERSON': ['sam', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['paul', 'csd', 'csd', 'uwm'], 'DATE': ['monday', 'yesterday', 'yesterday', 'last', 'year', 'last', 'year', 'yesterday', 'today'], 'PERSON': ['paul', 'csd', 'csd', '-PRON-', 'jamie', 'navarro', 'hamilton', 'batting', 'jaha', ' ', 'vaughn', '-PRON-', 'lloyd', 'maldanado', 'william', 'suero', 'tim', 'mcintosh'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['stanford', 'stanford'], 'DATE': [], 'PERSON': ['craig', 'meyer', 'jack', 'morris', 'michael', 'chen', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'craig'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['mellon', 'pittsburgh', 'american', 'edu'], 'DATE': [], 'PERSON': ['robert', 'everett', 'brunskill', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['sci', 'national', 'university', 'singapore', 'singapore'], 'DATE': [], 'PERSON': [], 'LOC': []}
# ---------------------------------------
# {'ORG': ['louisiana', 'tech', 'university', 'honda', 'delete', '-PRON-', '-PRON-'], 'DATE': ['sunday'], 'PERSON': ['charles', 'sundheim', 'max', 'james', 'dean'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['usl', 'forget'], 'DATE': [], 'PERSON': ['tg', 'cs', 'toronto', 'tom', 'glinos', '-PRON-', '-PRON-', 'tom', 'glinos', 'tos', 'tg'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['tm', 'msu', 'international', 'space', 'university', 'mac', 'tm', 'ibm'], 'DATE': [], 'PERSON': ['tom', 'subject', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'tom', 'mcwilliams'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['boston', 'university'], 'DATE': [], 'PERSON': ['johnc', 'crsa', 'john', 'collins'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['dlecoint', 'garnet', 'acns', 'fsu', 'edu'], 'DATE': [], 'PERSON': ['-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['stanford', 'university'], 'DATE': [], 'PERSON': ['xenon', 'stanford', 'eugene', 'kuo', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['ken', 'mitchum', 'rubin', 'ken', 'mitchum', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['cs', 'duke', 'edu', 'eduard', 'stanford', 'st', 'caucasian', 'army', 'corps'], 'DATE': ['september', 'eight', 'day', 'armenians', 'moslem', 'eight', 'day', 'today'], 'PERSON': ['-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['white', 'house', 'white', 'house'], 'DATE': [], 'PERSON': ['carl', 'ellison', '-PRON-', 'carl', 'ellison', 'cme'], 'LOC': ['cme', 'ellisun']}
# ---------------------------------------
# {'ORG': ['eliot', 'lanmola', 'eliot', 'lanmola'], 'DATE': [], 'PERSON': ['-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['detroit', 'organization', 'plymouth', 'state', 'college', 'acc', 'qc', 'edu'], 'DATE': [], 'PERSON': [], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': [], 'LOC': []}
# ---------------------------------------
# {'ORG': ['unc', 'edu', 'organization', 'university', 'north', 'carolina', 'nasa', 'nasa', 'esa', 'project', 'design', 'los', 'alamos', 'national', 'laboratory', 'delta', 'ii', 'srl', 'u', 'space', 'delta', 'ii'], 'DATE': ['october', 'june', 'three', 'half', 'year', 'one', 'martian', 'year', ' ', 'day', 'several', 'year', 'february', 'september', 'every', 'six', 'month', 'june', 'lifetime', '  ', 'year'], 'PERSON': ['schedule', 'press', 'angstrom', 'x', 'ray', 'telescope', '-PRON-', 'surface', 'jean', 'dominique', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'jeffrey', 'j', 'lanl', '-PRON-', '-PRON-', '-PRON-', 'star'], 'LOC': ['jupiter', 'jovian', 'moon', 'jupiter', 'jupiter', 'north', 'pole', 'gravity', 'jupiter']}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['jason', 'jason'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['-PRON-'], 'DATE': [], 'PERSON': ['bill', 'west', 'msi', 'bill', 'poitras', 'inc', 'x', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'modify', 'xtrap'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['informix', 'software', 'inc', 'informix', 'software', 'inc'], 'DATE': [], 'PERSON': ['william', 'daul', 'bill', 'william', 'bohannon'], 'LOC': ['sf', 'bay', 'area']}
# ---------------------------------------
# {'ORG': ['arizona', 'state', 'university', 'gowan'], 'DATE': [], 'PERSON': ['joe', 'cocker', 'charles', 'neville'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['ford', 'automobile', 'organization', 'hewlett', 'packard', 'ford', 'ford', 'chevrolet'], 'DATE': [], 'PERSON': ['steve', 'phillips', 'atlanta', 'x', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['seth', 'finkelstein', 'massachvsetts', 'institvte', 'whois', 'h', 'rs', 'seth', 'finkelstein'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['cs', 'dept', 'university'], 'DATE': ['saturday'], 'PERSON': ['lwb', 'cs', 'nyx', 'cs', 'du', 'zeik', 'w', 'bledsoe', 'lwb', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['chris', 'blask', 'subject', '-PRON-', 'mississauga', 'ontario', 'canada', '-PRON-', '-PRON-', '-PRON-', 'bobby', '-PRON-', 'joshua', 'jawbone', 'bobby', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'stomache', 'bobby', '-PRON-', '-PRON-', 'bobby'], 'LOC': ['south', 'america', 'middle', 'east', 'africa', 'africa']}
# ---------------------------------------
# {'ORG': ['digital', 'equipment', 'corp', '  '], 'DATE': [], 'PERSON': ['-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['-PRON-', 'u', '-PRON-', 'stanford', 'dashnak', 'russian', 'armenia', 'organize', 'revolt', 'city', 'stanford', 'university', 'press', 'london', ' ', 'national', 'bureau', 'tiflis', 'eastern', 'anatolia', 'national', 'council', '-PRON-', 'british', 'army', 'supreme', 'command', 'russian', 'caucasian', 'army', 'erzincan', 'erzurum'], 'DATE': ['month', 'century', 'one', 'thousand', 'year', 'one', 'thousand', 'year', 'today', 'four', 'time', 'row', 'century', 'three', 'week', 'century', 'month', 'month', 'april', 'april', 'next', 'two', 'day', 'november', 'mid', 'july', 'august', 'zilkade', '  ', 'september', 'october', 'april', 'every', 'day', 'two', 'year', 'today'], 'PERSON': ['neil', 'bernstein', 'zangezour', 'surmali', 'etchmiadzin', 'zangibasar', '-PRON-', 'pervert', 'baikar', 'press', 'boston', '  ', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'de', 'guerre', 'du', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'muslim', '-PRON-', 'muslim', '-PRON-', 'mutlu', '-PRON-', '-PRON-', 'mutlu', 'mark', 'bristol', '-PRON-', '-PRON-', '-PRON-', 'john', 'dewey', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'mccarthy', 'prof', 'shaw', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'nicholas', 'ii', '-PRON-', '-PRON-', 'yoke', '-PRON-', 'ali', 'ihsan', 'van', 'russian', 'protection', '-PRON-', 'meclis', 'vukela', 'babi', 'ali', 'evrak', 'odasi', 'van', 'ihtilali', '-PRON-', 'pseudo', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'armenian', '-PRON-', 'plan', 'kar', 'kar', '-PRON-', 'nesim', 'mazelyah', 'gang', 'murder', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'lung', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': ['europe', 'europe']}
# ---------------------------------------
# {'ORG': ['callison', 'uokmax', 'ecn', 'uoknor', 'uokmax', 'ecn', 'uoknor', 'matthew', 'macintyre', 'national', 'university', 'uokmax', 'ecn', 'uoknor', '-PRON-', 'u', 'oklahoma', 'uokmax', 'ecn', 'uoknor'], 'DATE': [], 'PERSON': ['james', 'p', 'callison', 'matmcinn', 'nuscc', 'james', 'p', 'callison', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': ['day', 'ago'], 'PERSON': ['harry', 'neuron', 'jpl', 'nasa', 'harry', 'langenbacher', 'jpl', 'pasadena', '-PRON-', '-PRON-', 'harry', 'neuron'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['-PRON-', 'nj', 'usa'], 'DATE': [], 'PERSON': ['usa', 'keyword', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['ann', 'arbor', 'michigan', 'usa'], 'DATE': [], 'PERSON': ['robert', 'desonia', 'us', 'robert', 'desonia', 'robert', 'desonia', 'us', 'robert', 'desonia'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['ssc', 'inc', 'romex', 'house'], 'DATE': [], 'PERSON': ['austin', 'ibm', 'zenier', 'markz', 'markz', 'ssc'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['hewlett', 'packard'], 'DATE': ['last', 'week'], 'PERSON': ['roger', 'hpscit', 'roger', 'mullane', '-PRON-', '-PRON-', '-PRON-', 'k', 'mile', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': ['textual'], 'PERSON': ['john', 'bruno', '-PRON-', 'john', 'bruno'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['-PRON-', '-PRON-', '-PRON-', 'tom', 'branham', 'branham'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': ['several', 'month'], 'PERSON': ['rushdie', 'islamic', '-PRON-', '-PRON-', 'khomeini', '-PRON-', 'rushdie', '-PRON-', 'khomeini', '-PRON-', 'muddy', '-PRON-', 'khomeini', 'fatwa', '-PRON-', 'khomeini', 'fatwa', '-PRON-', '-PRON-', 'fatwa', 'rushdie', '-PRON-', '-PRON-', 'rushdie', '-PRON-', 'rushdie', 'rushdie', '-PRON-', 'rushdie'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['scott', 'w', 'roby', 'fbi', 'fbi', 'nsc'], 'DATE': ['today', 'several', 'week', 'ago', 'several', 'week', 'ago'], 'PERSON': ['andrew', 'betz', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'fema', 'clinton', 'gore', 'insurrection', 'cia', 'mi', 'mi', 'kgb'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['edb', 'dmssyd', 'syd', 'theatre', 'macquarie', 'university', 'sydney', 'date', '  ', '-PRON-', 'recognition', 'inc'], 'DATE': ['december', 'june', 'august', 'october', 'thursday', 'december', 'daily'], 'PERSON': ['-PRON-', 'k', 'robertson', 'csiro', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['recognize', 'usa'], 'DATE': ['november'], 'PERSON': ['walveranta', '-PRON-', '-PRON-', 'las', 'vegas', 'walveranta', 'linda'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['eliot', 'lanmola', 'eliot', 'lanmola', '-PRON-'], 'DATE': [], 'PERSON': ['motor', 'head', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['sgi', 'silicon', 'graphics', 'inc', 'mountain', 'sgi', 'silicon', 'graphics', 'inc', 'maria'], 'DATE': [], 'PERSON': ['dave', 'olson', 'dan', 'jones', '-PRON-', 'dave', 'olson', 'barreno', 'olson', 'sgi'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['microsoft', 'foundation', 'organization', 'spss', 'inc', 'distribution', 'usa', 'line', ' ', 'article', 'qvrc', 'fcp', 'news', 'inc', 'chicago'], 'DATE': [], 'PERSON': ['ralph', 'spss', 'ralph', 'brendler', 'cs', 'tu', 'berlin', 'de', 'make', 'cs', 'tu', 'berlin', 'de', 'kerkhoff', 'void', 'void', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'mike', 'royko', 'spss'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['beck', 'irzr', 'inf', 'tu', 'dresden', 'de', 'andre', 'beck', 'subject', 'font', 'uow', 'edu', 'g', 'wampyr', 'uow', 'edu', 'white', 'times'], 'DATE': [], 'PERSON': ['andre', 'beck', 'irs', 'inf', 'tu', 'dresden', 'de', 'nntp', 'inf', 'tu', 'dresden', 'de', 'keywords', '-PRON-', '-PRON-', 'noel', 'make', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'andre', 'beck', 'abpsoft', 'mehl', 'andre', 'beck', 'irs', 'tu', 'dresden', 'de'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['buffalo', 'edu', 'article', ' ', 'hydra', 'gatech', 'buffalo', 'edu', 'mario', 'lemieux', 'buffalo', 'edu', 'lemieux'], 'DATE': ['three', 'day'], 'PERSON': ['valerie', 'hammerl', '-PRON-', 'glenn', 'healy', 'nyi', 'tommy', '-PRON-', 'valerie'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': [], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': [], 'PERSON': ['-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': [], 'DATE': ['december', 'today'], 'PERSON': ['tim', 'clock', 'armenischen', 'gesselschaft', 'clear', 'berlin', ' ', 'nazi', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['k', 'simms', 'helsinki', 'university', 'motorola'], 'DATE': [], 'PERSON': ['rubin', 'cis', 'rubin', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['organization', 'oracle', 'corp', 'redwood'], 'DATE': [], 'PERSON': ['eric', 'bosco', 'monica', 'us', 'oracle', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'motherboard', 'simms', 'eric', 'ebosco'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['louisiana', 'tech', 'university', 'delete', '-PRON-', '-PRON-'], 'DATE': [], 'PERSON': ['tony', 'jones', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['organization', 'university', 'colorado', 'boulder', 'line', ' ', 'ama', ' ', 'cbr', 'cbr'], 'DATE': [], 'PERSON': ['nicholas', 'coburn', '-PRON-', '-PRON-', '-PRON-', '-PRON-'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['united', 'states', 'u', 'newswire', 'reserve', 'officer', 'association', 'congress', 'senate', 'armed', 'services', 'committee', 'roa', 'navy', 'navy', 'alameda', 'calif', ' ', 'naval', 'reserve', 'center', 'macon', 'ga', 'parkersburg', 'w', 'va', 'missoula', 'great', 'fall', 'mont', 'marine', 'corps', 'reserve', 'center', 'mont', 'texas', 'major', 'marine', 'reserve', 'center', 'el', 'toro', 'calif', 'plus'], 'DATE': ['april', 'today', 'today'], 'PERSON': ['ndallen', 'r', 'node', 'nigel', 'allen', 'herbert', 'hart', '-PRON-', 'sen', 'sam', 'nunn', 'ga', 'gen', 'evan', 'l', 'aus', 'ret', '-PRON-', 'nigel', 'allen', 'ontario', 'canada', 'ndallen', 'r', 'node'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['organization', 'salomon', 'brothers', 'ltd'], 'DATE': [], 'PERSON': ['cwi', 'nl', '-PRON-', '-PRON-'], 'LOC': ['delta']}
# ---------------------------------------
# {'ORG': ['organization', 'department', 'computer', 'science', 'university', 'york', 'england'], 'DATE': ['eight', 'hundred', 'year'], 'PERSON': ['-PRON-', '-PRON-', '-PRON-', '-PRON-', 'chris', 'ho', 'stuart'], 'LOC': []}
# ---------------------------------------
# {'ORG': ['-PRON-'], 'DATE': [], 'PERSON': ['tmc', 'spartan', 'ac', 'brocku', 'tim', 'ciceran', 'ac', 'brocku', 'ca'], 'LOC': []}
